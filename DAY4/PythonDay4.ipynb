# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON/blob/main/DAY4/PythonDay4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DAY4

# %%
#TAKING USER INPUT

# %%
#Dynamic software:-where you interact with software
#input()-------> built in function

# %%
input("WHAT IS YOUR NAME?")
# Out:
# WHAT IS YOUR NAME?SNEHA
# 'SNEHA'

# %%
first_num=input("ENTER FIRST NUMBER")
second_num=input("ENTER SECOND NUMBER")
print(first_num+second_num)
# Out:
# ENTER FIRST NUMBER6
# ENTER SECOND NUMBER7
# 67

# %%
#this happen because

# %%
#INPUT IS ALWAYS TAKEN AS A STRING
#STRING IS A UNIVERSAL PATTERN

# %%
#TO AVOID THIS WE USE TYPE CONVERSION

# %%
#Implicit--> python does it on own

# %%
#Explicit-->done by user

# %%
4.5+4  #AUTOMATIC TYPE CONVERSION
# Out:
# 8.5

# %%
#Ever datatype has a type conversion function
#Type conversion is not a permanent operation

# %%
result=int(first_num)+int(second_num)
print(result)
# Out:
# 13
