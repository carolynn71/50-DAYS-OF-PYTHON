# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON/blob/main/DAY1/pythonDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DAY1

# %%
#CALL PRINT FUNCTION

# %%
print("hello world")
# Out:
# hello world

# %%
print(6)
print(5.6)
print(False)
print("INDIA","CHINA","NEPAL")
print("INDIA",5,True)
#can print anything
# Out:
# 6
# 5.6
# False
# INDIA CHINA NEPAL
# INDIA 5 True

# %%
#print function parameter
print(5,3,7,8,9,sep='--')
#the elements are seperated by the sep value
# Out:
# 5--3--7--8--9

# %%
#print function has end \n -->automatically
print("hello",end=' ')
print("world")
# Out:
# hello world

# %%
#DATATYPES IN PYTHON

# %%
#Python supports 3 categories of datatypes:
#BASIC TYPES
#CONTAINER TYPES
#USER-DEFINED TYPES

# %%
print(4)
#any number-integer
# Out:
# 4

# %%
print(4.5)
#any decimal-float
# Out:
# 4.5

# %%
print(True)
print(False)
#boolean
# Out:
# True
# False

# %%
print(4+5j)
#complex
# Out:
# (4+5j)

# %%
print("hyderabad")
print("Charminar")
#string
# Out:
# hyderabad
# Charminar

# %%
print([1,2,3,4,5])
#list
# Out:
# [1, 2, 3, 4, 5]

# %%
print((1,2,3,4,5))
#tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
print({1,2,3,4,5})
#sets
# Out:
# {1, 2, 3, 4, 5}

# %%
print({"NAME":"SNEHA"})
#dictionary
# Out:
# {'NAME': 'SNEHA'}
