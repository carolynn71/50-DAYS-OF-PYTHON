# %% [markdown]
# <a href="https://colab.research.google.com/github/carolynn71/50-DAYS-OF-PYTHON/blob/main/DAY3/PythonDay3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#DAY 3

# %%
#KEYWORKS AND IDENTIFIERS

# %%
#KEYWORDS

# %%
#python is a case sensitive programming language
#it has 33 keywords

# %%
#A keyword is a word that is reserved by a program beacuse the word has a special meaning
#Keywork can be commands or parameters

# %%
#Every programming language has a set of keywords that cannot be used as a variable name

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#compiler gives keywords a special meaning
#variable names cannot be keywords, compiler will still throw a error

# %%
#IDENTIFIERS

# %%
#A python identifier is a name used to identify a variable, function,class,module or other objects

# %%
#RULES

# %%
#rule 1- can only start with an alphabet or _
#ruel 2-followed by 0 or more letter,_ and digits
#rule 3-keywords cannot be used as identifiers

# %%
_name0="sneha"
print(_name0)
# Out:
# sneha
